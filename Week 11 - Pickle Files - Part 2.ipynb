# %% [markdown]
# # Week 11 - Pickle Files
# #### Part 2
# ### Notebook created by Jonathan Penava
# By the end of this lesson you should know the steps to create and read a Pickle file

# %% [markdown]
# ## Overview
# - Making a Pickle file
# - <span style="color:red;">Reading a Pickle file</span>

# %% [markdown]
# Now we want to read in the file we just created.

# %%
import pickle

# %%
#We open our file to read, rb stands for read and binary
#We store the newly opened file as a variable
model_pkl = open("titanic_logistic_model.pkl", "rb")

# %%
#We now load in our saved model into a model variable
model = pickle.load(model_pkl)

# %% [markdown]
# Our "model" variable is now the same as the "logmodel" we had in our previous project.  Let's see what our inputs are:

# %%
model.feature_names_in_
# Out:
# array(['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'who',
#        'adult_male', 'alone'], dtype=object)

# %% [markdown]
# Remember in the prevous part we did X.iloc[0].to_dict(), let's copy and paste it in here as a variable.  Feel free to modify it to what you want them to be.

# %%
mytest = {'pclass': 1,
 'sex': 1,
 'age': 22.0,
 'sibsp': 1,
 'parch': 0,
 'fare': 7.25,
 'who': 0,
 'adult_male': True,
 'alone': False}

# %%
import pandas as pd

# %%
df = pd.DataFrame([mytest])
print(model.predict(df))
# Out:
# [1]
