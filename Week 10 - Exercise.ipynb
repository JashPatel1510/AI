# %% [markdown]
# # Week 10 - Exercise
# ### Notebook created by Jonathan Penava

# %% [markdown]
# For this exercise you are going to modify your week 9 exercise to be a web service.  <br><br>
# Have a sample URL that will return an example of JSON input. <br><br>
# Have an evaluate URL that will return the carat range based on the input. <br><br>
# Create a separate notebook (Notes Part 3) that will test out your URL's
