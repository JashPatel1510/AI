# %% [markdown]
# # Week 5 - Decision Trees and Random Forests
# #### Part 3
# ### Notebook created by Jonathan Penava
# By the end of this lesson you should know what a decision tree algorithm is, how it is constructed, and how to create a machine learning algorithm that uses decision trees.

# %% [markdown]
# ## Overview
# - Data Mining vs Machine Learning
# - Decision Trees in Detail
# - <span style="color:red;">Decision Tree Example</span>
# - Random Forests

# %% [markdown]
# Let's run through some of the basic steps that we covered before

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

titanic = sns.load_dataset('titanic')

titanic.drop('embark_town', axis=1, inplace=True)
titanic.drop('embarked', axis=1, inplace=True)
titanic.drop('deck', axis=1, inplace=True)
titanic.drop('class', axis=1, inplace=True)
titanic.drop('alive', axis=1, inplace=True)

titanic.replace('male', 0, inplace=True)
titanic.replace('female', 1, inplace=True)
titanic.replace('man', 0, inplace=True)
titanic.replace('woman', 1, inplace=True)
titanic.replace('child', 2, inplace=True)

titanic.dropna(axis=0, inplace=True)

#Remove the dependent data (our y) from our independent data (our x values)
X, y = titanic.drop('survived', axis=1), titanic['survived'].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=87)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11284\2648543462.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   titanic.replace('female', 1, inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_11284\2648543462.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   titanic.replace('child', 2, inplace=True)

# %% [markdown]
# Now that we have our training data, let's use the decision tree model as our algorithm.

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)

predictions = dtree.predict(X_test)

from sklearn.metrics import classification_report

#####
#Use the trained algorithm to make a prediction.
#####

print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       130
#            1       0.70      0.78      0.74        85
#
#     accuracy                           0.78       215
#    macro avg       0.77      0.78      0.78       215
# weighted avg       0.79      0.78      0.78       215

# %% [markdown]
# Not quite as accurate as our logistic regression.  We saw this report in our previous class, let's go into a little more detail about what each of these columns are.
#
# We have 4 possibilities:
# <ul>
# <li>TN - True Negative</li>
# <li>TP - True Positive</li>
# <li>FN - False Negative</li>
# <li>FP - False Positive</li>
# </ul>
# <br>
# Presicion - Measures the accuracy of our positive predictions. <br>
# Precision = TP / (TP + FP)<br>
# <br>
# Recall - The percentage of positive cases that were correctly identified.<br>
# Recall = TP / (TP + FN) <br>
# <br>
# F1 Socre - The percent of positive predictions that were correct.<br>
# F1 Socre = 2*(Recall * Precision) / (Recall + Precision) <br>

# %% [markdown]
# We can also see the tree diagram that our model created.

# %%
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  who  adult_male  alone
# 0         0       3    0  22.0      1      0   7.2500    0        True  False
# 1         1       1    1  38.0      1      0  71.2833    1       False  False
# 2         1       3    1  26.0      0      0   7.9250    1       False   True
# 3         1       1    1  35.0      1      0  53.1000    1       False  False
# 4         0       3    0  35.0      0      0   8.0500    0        True   True

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(80, 40))  # Set the figure size
fn = ['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'who', 'adult_male', 'alone']
cn = ['Died', 'Survived']
plot_tree(dtree, filled=True, feature_names=fn, class_names=cn)
# Out:
# [Text(0.42416039937759337, 0.9666666666666667, 'adult_male <= 0.5\ngini = 0.484\nsamples = 499\nvalue = [294, 205]\nclass = Died'),
#  Text(0.17894190871369295, 0.9, 'pclass <= 2.5\ngini = 0.409\nsamples = 209\nvalue = [60, 149]\nclass = Survived'),
#  Text(0.30155115404564314, 0.9333333333333333, 'True  '),
#  Text(0.07883817427385892, 0.8333333333333334, 'fare <= 28.856\ngini = 0.14\nsamples = 119\nvalue = [9, 110]\nclass = Survived'),
#  Text(0.06224066390041494, 0.7666666666666667, 'fare <= 28.231\ngini = 0.237\nsamples = 51\nvalue = [7.0, 44.0]\nclass = Survived'),
#  Text(0.05394190871369295, 0.7, 'age <= 55.5\ngini = 0.211\nsamples = 50\nvalue = [6, 44]\nclass = Survived'),
#  Text(0.04564315352697095, 0.6333333333333333, 'age <= 23.5\ngini = 0.183\nsamples = 49\nvalue = [5, 44]\nclass = Survived'),
#  Text(0.03734439834024896, 0.5666666666666667, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = Survived'),
#  Text(0.05394190871369295, 0.5666666666666667, 'age <= 27.5\ngini = 0.239\nsamples = 36\nvalue = [5, 31]\nclass = Survived'),
#  Text(0.03319502074688797, 0.5, 'age <= 25.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]\nclass = Survived'),
#  Text(0.016597510373443983, 0.43333333333333335, 'alone <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Survived'),
#  Text(0.008298755186721992, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.024896265560165973, 0.36666666666666664, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.04979253112033195, 0.43333333333333335, 'fare <= 17.429\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.04149377593360996, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.058091286307053944, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.07468879668049792, 0.5, 'age <= 36.5\ngini = 0.137\nsamples = 27\nvalue = [2, 25]\nclass = Survived'),
#  Text(0.06639004149377593, 0.43333333333333335, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = Survived'),
#  Text(0.08298755186721991, 0.43333333333333335, 'age <= 39.0\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Survived'),
#  Text(0.07468879668049792, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.0912863070539419, 0.36666666666666664, 'fare <= 25.965\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Survived'),
#  Text(0.08298755186721991, 0.3, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Survived'),
#  Text(0.0995850622406639, 0.3, 'fare <= 26.86\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.0912863070539419, 0.23333333333333334, 'age <= 43.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.08298755186721991, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.0995850622406639, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.1078838174273859, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.06224066390041494, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.07053941908713693, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.0954356846473029, 0.7666666666666667, 'parch <= 1.5\ngini = 0.057\nsamples = 68\nvalue = [2, 66]\nclass = Survived'),
#  Text(0.08713692946058091, 0.7, 'gini = 0.0\nsamples = 55\nvalue = [0, 55]\nclass = Survived'),
#  Text(0.1037344398340249, 0.7, 'fare <= 135.775\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Survived'),
#  Text(0.0954356846473029, 0.6333333333333333, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Survived'),
#  Text(0.11203319502074689, 0.6333333333333333, 'fare <= 206.963\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.1037344398340249, 0.5666666666666667, 'sex <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.0954356846473029, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.11203319502074689, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.12033195020746888, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.279045643153527, 0.8333333333333334, 'fare <= 20.8\ngini = 0.491\nsamples = 90\nvalue = [51, 39]\nclass = Died'),
#  Text(0.21369294605809128, 0.7666666666666667, 'age <= 17.5\ngini = 0.489\nsamples = 61\nvalue = [26, 35]\nclass = Survived'),
#  Text(0.16182572614107885, 0.7, 'fare <= 13.935\ngini = 0.287\nsamples = 23\nvalue = [4, 19]\nclass = Survived'),
#  Text(0.14522821576763487, 0.6333333333333333, 'age <= 3.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = Survived'),
#  Text(0.13692946058091288, 0.5666666666666667, 'fare <= 10.798\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.12863070539419086, 0.5, 'sex <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.12033195020746888, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.13692946058091288, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.14522821576763487, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.15352697095435686, 0.5666666666666667, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Survived'),
#  Text(0.17842323651452283, 0.6333333333333333, 'age <= 7.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Survived'),
#  Text(0.17012448132780084, 0.5666666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.18672199170124482, 0.5666666666666667, 'age <= 14.75\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.17842323651452283, 0.5, 'sex <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.17012448132780084, 0.43333333333333335, 'age <= 10.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.16182572614107885, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.17842323651452283, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.18672199170124482, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.1950207468879668, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.26556016597510373, 0.7, 'fare <= 20.231\ngini = 0.488\nsamples = 38\nvalue = [22, 16]\nclass = Died'),
#  Text(0.2572614107883817, 0.6333333333333333, 'fare <= 9.413\ngini = 0.475\nsamples = 36\nvalue = [22, 14]\nclass = Died'),
#  Text(0.21991701244813278, 0.5666666666666667, 'fare <= 8.673\ngini = 0.498\nsamples = 15\nvalue = [7, 8]\nclass = Survived'),
#  Text(0.21161825726141079, 0.5, 'age <= 28.0\ngini = 0.497\nsamples = 13\nvalue = [7, 6]\nclass = Died'),
#  Text(0.2033195020746888, 0.43333333333333335, 'age <= 18.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = Survived'),
#  Text(0.1950207468879668, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.21161825726141079, 0.36666666666666664, 'fare <= 8.258\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Survived'),
#  Text(0.2033195020746888, 0.3, 'age <= 23.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.1950207468879668, 0.23333333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.21161825726141079, 0.23333333333333334, 'age <= 25.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.2033195020746888, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.21991701244813278, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.21991701244813278, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.21991701244813278, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.22821576763485477, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.2946058091286307, 0.5666666666666667, 'age <= 54.0\ngini = 0.408\nsamples = 21\nvalue = [15, 6]\nclass = Died'),
#  Text(0.2863070539419087, 0.5, 'parch <= 1.5\ngini = 0.375\nsamples = 20\nvalue = [15, 5]\nclass = Died'),
#  Text(0.2697095435684647, 0.43333333333333335, 'sibsp <= 2.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]\nclass = Died'),
#  Text(0.26141078838174275, 0.36666666666666664, 'age <= 25.0\ngini = 0.219\nsamples = 16\nvalue = [14, 2]\nclass = Died'),
#  Text(0.25311203319502074, 0.3, 'age <= 23.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = Died'),
#  Text(0.24481327800829875, 0.23333333333333334, 'alone <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Died'),
#  Text(0.23651452282157676, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.25311203319502074, 0.16666666666666666, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.24481327800829875, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.26141078838174275, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.26141078838174275, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.2697095435684647, 0.3, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Died'),
#  Text(0.27800829875518673, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3029045643153527, 0.43333333333333335, 'age <= 35.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.2946058091286307, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.3112033195020747, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.3029045643153527, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.27385892116182575, 0.6333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.34439834024896265, 0.7666666666666667, 'age <= 6.0\ngini = 0.238\nsamples = 29\nvalue = [25, 4]\nclass = Died'),
#  Text(0.3278008298755187, 0.7, 'parch <= 1.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Died'),
#  Text(0.31950207468879666, 0.6333333333333333, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.3360995850622407, 0.6333333333333333, 'fare <= 31.331\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.3278008298755187, 0.5666666666666667, 'sibsp <= 2.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.31950207468879666, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3360995850622407, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.34439834024896265, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.36099585062240663, 0.7, 'parch <= 4.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = Died'),
#  Text(0.35269709543568467, 0.6333333333333333, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Died'),
#  Text(0.36929460580912865, 0.6333333333333333, 'age <= 38.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.36099585062240663, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3775933609958506, 0.5666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.6693788900414938, 0.9, 'pclass <= 1.5\ngini = 0.312\nsamples = 290\nvalue = [234.0, 56.0]\nclass = Died'),
#  Text(0.5467696447095436, 0.9333333333333333, '  False'),
#  Text(0.46473029045643155, 0.8333333333333334, 'age <= 36.5\ngini = 0.482\nsamples = 74\nvalue = [44, 30]\nclass = Died'),
#  Text(0.4190871369294606, 0.7666666666666667, 'fare <= 37.812\ngini = 0.477\nsamples = 28\nvalue = [11, 17]\nclass = Survived'),
#  Text(0.3941908713692946, 0.7, 'fare <= 27.15\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = Survived'),
#  Text(0.38589211618257263, 0.6333333333333333, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Survived'),
#  Text(0.4024896265560166, 0.6333333333333333, 'fare <= 28.875\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Survived'),
#  Text(0.3941908713692946, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.4107883817427386, 0.5666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.44398340248962653, 0.7, 'fare <= 387.665\ngini = 0.484\nsamples = 17\nvalue = [10, 7]\nclass = Died'),
#  Text(0.43568464730290457, 0.6333333333333333, 'fare <= 123.258\ngini = 0.444\nsamples = 15\nvalue = [10, 5]\nclass = Died'),
#  Text(0.42738589211618255, 0.5666666666666667, 'fare <= 52.55\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.4190871369294606, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.43568464730290457, 0.5, 'age <= 33.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = Survived'),
#  Text(0.42738589211618255, 0.43333333333333335, 'age <= 22.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Survived'),
#  Text(0.4190871369294606, 0.36666666666666664, 'parch <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.4107883817427386, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.42738589211618255, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.43568464730290457, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.44398340248962653, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.44398340248962653, 0.5666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.45228215767634855, 0.6333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.5103734439834025, 0.7666666666666667, 'sibsp <= 0.5\ngini = 0.405\nsamples = 46\nvalue = [33.0, 13.0]\nclass = Died'),
#  Text(0.49377593360995853, 0.7, 'fare <= 31.66\ngini = 0.32\nsamples = 30\nvalue = [24, 6]\nclass = Died'),
#  Text(0.4854771784232365, 0.6333333333333333, 'age <= 72.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]\nclass = Died'),
#  Text(0.47717842323651455, 0.5666666666666667, 'age <= 53.0\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = Died'),
#  Text(0.46887966804979253, 0.5, 'age <= 46.75\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.4605809128630705, 0.43333333333333335, 'fare <= 30.35\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Died'),
#  Text(0.45228215767634855, 0.36666666666666664, 'age <= 41.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Died'),
#  Text(0.44398340248962653, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.4605809128630705, 0.3, 'age <= 43.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.45228215767634855, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.46887966804979253, 0.23333333333333334, 'age <= 45.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.4605809128630705, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.47717842323651455, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.46887966804979253, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.47717842323651455, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.4854771784232365, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.49377593360995853, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5020746887966805, 0.6333333333333333, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Died'),
#  Text(0.5269709543568465, 0.7, 'fare <= 52.277\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = Died'),
#  Text(0.5186721991701245, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.5352697095435685, 0.6333333333333333, 'fare <= 52.827\ngini = 0.498\nsamples = 15\nvalue = [8, 7]\nclass = Died'),
#  Text(0.5269709543568465, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.5435684647302904, 0.5666666666666667, 'fare <= 56.415\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = Died'),
#  Text(0.5352697095435685, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.5518672199170125, 0.5, 'age <= 41.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.5435684647302904, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5601659751037344, 0.43333333333333335, 'age <= 47.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Died'),
#  Text(0.5518672199170125, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.5684647302904564, 0.36666666666666664, 'fare <= 97.765\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Survived'),
#  Text(0.5601659751037344, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.5767634854771784, 0.3, 'sibsp <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.5684647302904564, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.5850622406639004, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.874027489626556, 0.8333333333333334, 'fare <= 48.092\ngini = 0.212\nsamples = 216\nvalue = [190, 26]\nclass = Died'),
#  Text(0.764652489626556, 0.7666666666666667, 'age <= 32.25\ngini = 0.196\nsamples = 209\nvalue = [186, 23]\nclass = Died'),
#  Text(0.6247406639004149, 0.7, 'fare <= 7.01\ngini = 0.248\nsamples = 131\nvalue = [112, 19]\nclass = Died'),
#  Text(0.5684647302904564, 0.6333333333333333, 'age <= 22.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.5601659751037344, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.5767634854771784, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.6810165975103735, 0.6333333333333333, 'pclass <= 2.5\ngini = 0.232\nsamples = 127\nvalue = [110, 17]\nclass = Died'),
#  Text(0.5933609958506224, 0.5666666666666667, 'age <= 30.5\ngini = 0.064\nsamples = 30\nvalue = [29, 1]\nclass = Died'),
#  Text(0.5850622406639004, 0.5, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = Died'),
#  Text(0.6016597510373444, 0.5, 'fare <= 11.75\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.5933609958506224, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.6099585062240664, 0.43333333333333335, 'alone <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.6016597510373444, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.6182572614107884, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7686721991701245, 0.5666666666666667, 'age <= 28.75\ngini = 0.275\nsamples = 97\nvalue = [81, 16]\nclass = Died'),
#  Text(0.7116182572614108, 0.5, 'fare <= 7.825\ngini = 0.235\nsamples = 81\nvalue = [70, 11]\nclass = Died'),
#  Text(0.6597510373443983, 0.43333333333333335, 'fare <= 7.785\ngini = 0.328\nsamples = 29\nvalue = [23, 6]\nclass = Died'),
#  Text(0.6348547717842323, 0.36666666666666664, 'fare <= 7.24\ngini = 0.269\nsamples = 25\nvalue = [21, 4]\nclass = Died'),
#  Text(0.6099585062240664, 0.3, 'fare <= 7.133\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = Died'),
#  Text(0.6016597510373444, 0.23333333333333334, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.6182572614107884, 0.23333333333333334, 'fare <= 7.227\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Died'),
#  Text(0.6099585062240664, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.6265560165975104, 0.16666666666666666, 'age <= 21.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.6182572614107884, 0.1, 'age <= 18.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.6099585062240664, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.6265560165975104, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6348547717842323, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.6597510373443983, 0.3, 'alone <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Died'),
#  Text(0.6514522821576764, 0.23333333333333334, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.6431535269709544, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.6597510373443983, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.6680497925311203, 0.23333333333333334, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Died'),
#  Text(0.6846473029045643, 0.36666666666666664, 'age <= 19.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.6763485477178424, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.6929460580912863, 0.3, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.6846473029045643, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.7012448132780082, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7634854771784232, 0.43333333333333335, 'age <= 20.5\ngini = 0.174\nsamples = 52\nvalue = [47, 5]\nclass = Died'),
#  Text(0.7427385892116183, 0.36666666666666664, 'fare <= 8.104\ngini = 0.278\nsamples = 24\nvalue = [20, 4]\nclass = Died'),
#  Text(0.7261410788381742, 0.3, 'fare <= 7.91\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = Died'),
#  Text(0.7178423236514523, 0.23333333333333334, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.7344398340248963, 0.23333333333333334, 'alone <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Died'),
#  Text(0.7261410788381742, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7427385892116183, 0.16666666666666666, 'age <= 19.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.7344398340248963, 0.1, 'age <= 17.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.7261410788381742, 0.03333333333333333, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.7427385892116183, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7510373443983402, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.7593360995850622, 0.3, 'age <= 19.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Died'),
#  Text(0.7510373443983402, 0.23333333333333334, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Died'),
#  Text(0.7676348547717843, 0.23333333333333334, 'parch <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.7593360995850622, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.7759336099585062, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7842323651452282, 0.36666666666666664, 'fare <= 17.444\ngini = 0.069\nsamples = 28\nvalue = [27, 1]\nclass = Died'),
#  Text(0.7759336099585062, 0.3, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = Died'),
#  Text(0.7925311203319502, 0.3, 'fare <= 19.681\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.7842323651452282, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8008298755186722, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.8257261410788381, 0.5, 'fare <= 7.835\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = Died'),
#  Text(0.8174273858921162, 0.43333333333333335, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.8340248962655602, 0.43333333333333335, 'age <= 31.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.8174273858921162, 0.36666666666666664, 'fare <= 7.988\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Survived'),
#  Text(0.8091286307053942, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.8257261410788381, 0.3, 'fare <= 8.775\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.8174273858921162, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.8340248962655602, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.8506224066390041, 0.36666666666666664, 'fare <= 7.988\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.8423236514522822, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.8589211618257261, 0.3, 'sibsp <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.8506224066390041, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8672199170124482, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.9045643153526971, 0.7, 'age <= 43.5\ngini = 0.097\nsamples = 78\nvalue = [74, 4]\nclass = Died'),
#  Text(0.8838174273858921, 0.6333333333333333, 'age <= 34.5\ngini = 0.043\nsamples = 46\nvalue = [45, 1]\nclass = Died'),
#  Text(0.8755186721991701, 0.5666666666666667, 'pclass <= 2.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Died'),
#  Text(0.8672199170124482, 0.5, 'age <= 33.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.8589211618257261, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.8755186721991701, 0.43333333333333335, 'alone <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.8672199170124482, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.8838174273858921, 0.36666666666666664, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.8838174273858921, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Died'),
#  Text(0.8921161825726142, 0.5666666666666667, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]\nclass = Died'),
#  Text(0.9253112033195021, 0.6333333333333333, 'age <= 45.25\ngini = 0.17\nsamples = 32\nvalue = [29, 3]\nclass = Died'),
#  Text(0.9087136929460581, 0.5666666666666667, 'age <= 44.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Died'),
#  Text(0.9004149377593361, 0.5, 'fare <= 7.988\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.8921161825726142, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9087136929460581, 0.43333333333333335, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.91701244813278, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.941908713692946, 0.5666666666666667, 'age <= 61.5\ngini = 0.074\nsamples = 26\nvalue = [25, 1]\nclass = Died'),
#  Text(0.9336099585062241, 0.5, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Died'),
#  Text(0.950207468879668, 0.5, 'age <= 63.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Died'),
#  Text(0.941908713692946, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9585062240663901, 0.43333333333333335, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.983402489626556, 0.7666666666666667, 'fare <= 64.998\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Died'),
#  Text(0.975103734439834, 0.7, 'age <= 30.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.966804979253112, 0.6333333333333333, 'age <= 27.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.9585062240663901, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.975103734439834, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.983402489626556, 0.6333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.991701244813278, 0.7, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died')]
