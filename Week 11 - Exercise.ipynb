# %% [markdown]
# # Week 11 - Exercise
# ### Notebook created by Jonathan Penava

# %% [markdown]
# In this exercise I am not going to give you a dataset, or tell you what your dataset will be.  You will be getting it from one of your classmates.  My hope is that you trained an algorithm for your assignment 1, and you did a good job with it.  You are going to share that algorithm with a classmate, and they are going to use it to complete their exercise.

# %% [markdown]
# <span style="color:red;">Note: If you did not complete the assignment, or complete it properly, then use your exercise 8 or 9.</span>

# %% [markdown]
# Step 1: Package your trained model from your assignment as a pickle file.

# %% [markdown]
# Step 2: Email your pickle file to your group members.

# %% [markdown]
# Step 3: Get a pickle file from one of your group members.

# %% [markdown]
# Step 4: Using model.feature_names_in_ build a dictionary example with a sample record you would like to test.  Use your group members model to test your sample record.

# %% [markdown]
# <span style="color:red;">You need to demonstrate both the pickle file you created and the test record you used on your group members model.</span>
